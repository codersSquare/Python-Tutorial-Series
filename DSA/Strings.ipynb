# %% [markdown]
# #  <span style="color:blue">Strings in Python</span>

# %% [markdown]
# ### Strings in Python
#
# In Python, Strings are arrays of bytes representing Unicode characters.
#
# #### Example:
#
#
#
# "Geeksforgeeks" or 'Geeksforgeeks'
# Python does not have a character data type, a single character is simply a string with a length of 1. Square brackets can be used to access elements of the string.

# %%
print(ord("a"))     # chr to ord
print(ord("A"))
print(chr(97))      # ord to chr
print(chr(65))
# Out:
# 97
# 65
# a
# A

# %% [markdown]
# ### Indexing In String

# %%
s = "geek"

print(s)
print(s[0])
print(s[-1])
print(s[1])
print(s[-2])
# Out:
# geek
# g
# k
# e
# e

# %% [markdown]
# ### Strings are immutable

# %%
s = "geek"
s[0] = "e"  # error: item assignment not supported
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18800\2414630433.py in <module>
#       1 s = "geek"
# ----> 2 s[0] = "e"  # error: item assignment not supported
#       3 print(s)
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Multiline String

# %%
s = """ Hi,
This is python course.
Hope you are enjoying it. """
print(s)
# Out:
#  Hi,
# This is python course.
# Hope you are enjoying it.

# %% [markdown]
# #  <span style="color:blue">Escape Sequences and Raw Strings</span>

# %%
s='welcome tp Geek\'s course'
Print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18800\2837250817.py in <module>
#       1 s='welcome tp Geek\'s course'
# ----> 2 Print(s)
#
# NameError: name 'Print' is not defined

# %%
s="Hi \nwelcome to the course"
print(s)
# Out:
# Hi
# welcome to the course

# %%
s1="A simple \ example"
print(s1)
s2="Backslash at the end\\"
print(s2)
s3="\\n"
print(s3)
s4="\\t"
print(s4)
# Out:
# A simple \ example
# Backslash at the end\
# \n
# \t

# %%
s1="c:\project\name.py"
print(s1)

s2=r"c:\project\name.py"
print(s2)
# Out:
# c:\project
# ame.py
# c:\project\name.py

# %% [markdown]
# #  <span style="color:blue">String formatting
#
# </span>

# %% [markdown]
# String formatting is the process of infusing things in the string dynamically and presenting the string.
#
#
#
# ### There are four different ways to perform string formatting in Python:
# - Formatting with % Operator.
# - Formatting with format() string method.
# - Formatting with string literals, called f-strings.
# - Formatting with String Template Class
#
# So we will see the entirety of the above-mentioned ways, and we will also focus on which string formatting strategy is the best.

# %%
name = "ABC"

course = "Python Course"

s = "Welcome %s to the %s"%(name,course)
print(s)
print()
###########
# using format function

s = "welcome {0} to the {1}".format(name,course)
print(s)
print()
############################
# using f-string

s = f"welcome {name} to the {course}"
print(s)
print()
# Out:
# Welcome ABC to the Python Course
#
# welcome ABC to the Python Course
#
# welcome ABC to the Python Course

# %%
a = 10
b = 20

print(f"sum of {a} and {b} is {a + b}")
print(f"product of {a} and {b} is {a * b}")
# Out:
# sum of 10 and 20 is 30
# product of 10 and 20 is 200

# %%
s1  = "ABC"
s2 = "abc"

print(f"lower case of {s1} is {s1.lower()}")
print(f"upper case of {s2} is {s2.upper()}")
# Out:
# lower case of ABC is abc
# upper case of abc is ABC

# %% [markdown]
# #  <span style="color:blue">String Comparison in Python
#
# </span>

# %% [markdown]
# ### String Comparison in Python
#
# #### Method 1: Using Relational Operators
#
# The relational operators compare the Unicode values of the characters of the strings from the zeroth index till the end of the string. It then returns a boolean value according to the operator used.
#
# “Geek” == “Geek” will return True as the Unicode of all the characters are equal
#
# In case of “Geek” and “geek” as the unicode of G is \u0047 and of g is \u0067
# “Geek” < “geek” will return True and
# “Geek” > “geek” will return False

# %%
s1 = "geeksforgeeks"

s2 = "ide"

print(s1<s2)
print(s1<=s2)
print(s1>s2)
print(s1>=s2)
print(s1==s2)
print(s1 != s2)


print("#############")

print("abcd > abc ","abcd">"abc")
print("ZAB>ABC","ZAB">"ABC")

print("abc>ABC","abc">"ABC")

print("x>abcd","x">"abcd")
# Out:
# True
# True
# False
# False
# False
# True
# #############
# abcd > abc  True
# ZAB>ABC True
# abc>ABC True
# x>abcd True

# %% [markdown]
# #  <span style="color:blue">String Operations
#
# </span>

# %% [markdown]
# Python offers two membership operators to check or validate the membership of a value. It tests for membership in a sequence, such as strings, lists, or tuples.
#
# in operator: The ‘in’ operator is used to check if a character/ substring/ element exists in a sequence or not. Evaluate to True if it finds the specified element in a sequence otherwise False.
#
# ‘not in’ operator- Evaluates to true if it does not finds a variable in the specified sequence and false otherwise.

# %%
s1 = "geeksforgeeks"
s2 = "geeks"

print(s2 in s1)
print(s2 not in s1)
# Out:
# True
# False

# %% [markdown]
# ### String Concatenation using + Operator
# It’s very easy to use the + operator for string concatenation. This operator can be used to add multiple strings together. However, the arguments must be a string. Here, The + Operator combines the string that is stored in the var1 and var2 and stores in another variable var3.

# %%
s1 = "geeks"
s2 = "for"
s3 = s1 + s2

s4 = "welcome to " + s1 + s2

print(s3)
print(s4)
# Out:
# geeksfor
# welcome to geeksfor

# %%
s1 = "geeksforgeeks"
s2 = "geeks"

print(s1.index(s2))
print(s1.rindex(s2))        # right index
print(s1.index(s2,1,13))    # start and end index
# Out:
# 0
# 8
# 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s1 = "geeks"

print(len(s1))

s2 = s1.upper()

print(s2)

s3 = s2.lower()

print(s3)

print(s1.islower())

print(s2.isupper())
# Out:
# 5
# GEEKS
# geeks
# True
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = "GeeksforGeeks Python Course"

print(s.startswith("Geeks"))

print(s.endswith("Course"))

print(s.startswith("Geeks", 1))     # start index

print(s.startswith("Geeks",8,len(s)))   # start index, last-index
# Out:
# True
# True
# False
# True

# %% [markdown]
# ### Split in python

# %%
#SPLIT

s1 = "geeks for geeks"

print(s1.split())   # split by space ' '

s2 = "geeks, for, geeks"
print(s2.split(','))        # split by comma ','

l = ["geeksforgeeks","python","course"]

print(" ".join(l))          # join by space

print(", ".join(l))         # join by comma
# Out:
# ['geeks', 'for', 'geeks']
# ['geeks', ' for', ' geeks']
# geeksforgeeks python course
# geeksforgeeks, python, course

# %% [markdown]
# ### Strip in python

# %%
s1 = "__geeksforgeeks__"

print(s1.strip("_"))   # strip from both side


print(s1.lstrip('_'))  # strip from left side


print(s1.rstrip("_"))   # strip from right side
# Out:
# geeksforgeeks
# geeksforgeeks__
# __geeksforgeeks

# %% [markdown]
# ### Find function in python

# %%
s1 = "geeks for geeks"

s2 = "geeks"

print(s1.find(s2))

print(s1.find("gfg"))

n = len(s1)

print(s1.find(s2,1,n))
# Out:
# 0
# -1
# 10

# %% [markdown]
# #  <span style="color:blue">Reverse A String in Python
#
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def reverse(s):
    str = ""
    for i in s:
        str = i + str
    return str
  
s = "Geeksforgeeks"
  
print("The original string is : ")
print(s)
  
print("The reversed string(using loops) is : ")
print(reverse(s))
# Out:
# The original string is :
# Geeksforgeeks
# The reversed string(using loops) is :
# skeegrofskeeG

# %% [markdown]
# #  <span style="color:blue">Check if string is rotated
#
# </span>

# %%
# Check if string is rotated

def arerotations(s1,s2) :
    if len(s1) != len(s2) :
        return False
    temp = s1 + s1 
    return temp.find(s2)!= -1 
    
    
s1 = "ABDC"
s2 = "CDBA"

print(arerotations(s1,s2))
# Out:
# False

# %% [markdown]
# #  <span style="color:blue">Check For Palindrome In Python
# </span>

# %% [markdown]
# Given a string, write a python function to check if it is palindrome or not. A string is said to be palindrome if the reverse of the string is the same as string. For example, “radar” is a palindrome, but “radix” is not a palindrome

# %%
# function which return reverse of a string
 
def isPalindrome(s):
    return s == s[::-1]
 
 
# Driver code
s = "malayalam"
ans = isPalindrome(s)
 
if ans:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# #  <span style="color:blue">Check if a String is Subsequence of Other
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Check if a String is Subsequence of Other

def issubseq(s1,s2) :
    i, j = 0, 0
    while(i < len(s1) and j < len(s2)) :
        if s1[i] == s2[j] :
            j = j + 1 
        i += 1 
    if j == len(s2) :
        return True
    else :
        return False
        
s1 = "ABCDEF"
s2 = "ADE"

print(issubseq(s1,s2))
# Out:
# True

# %% [markdown]
# Time complexity: Because we are traversing throughout the strings then, time complexity will be O(max(n, m))
#
# Space complexity: As we are only using two extra variables i and j, then space complexity will be O(1)

# %%
## Efficient Approach

dp = [[-1]*1001]*1001

def isSubSequence(s1,s2,i,j):
    if (i == 0 or j == 0):
	    return 0

    if (dp[i][j] != -1):
	    return dp[i][j]

    if (s1[i - 1] == s2[j - 1]):
	    dp[i][j] = 1 + isSubSequence(s1, s2, i - 1, j - 1)
	    return dp[i][j]

    else:
	    dp[i][j] = isSubSequence(s1, s2, i, j - 1)
	    return dp[i][j]

str1 = "gksrek"
str2 = "geeksforgeeks"
m = len(str1)
n = len(str2)

if (m > n):
    print("NO")

if (isSubSequence(str1, str2, m, n) == m):
	print("YES")

else:
	print("NO")
# Out:
# YES

# %% [markdown]
# Time complexity: O(max(n, m))

# %% [markdown]
# #  <span style="color:blue">Check for Anagram in Python
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s1= input("Enter a String:\n")
s2= input("Enter a String:\n")

def areAnagram(s1,s2):
    if len(s1) != len(s2):
        return False
    s1=sorted(s1)
    s2=sorted(s2)
    return(s1==s2)
print(areAnagram(s1,s2))
# Out:
# Enter a String:
# sat
# Enter a String:
# tsa
# True

# %% [markdown]
# Time Complexity: O(n), where n is the size of string
#
# Space Complexity: O(n), because space required to store the sorted strings.

# %%
#Efficient

s1= input("Enter a String:\n")
s2= input("Enter a String:\n")

def areAnagram(s1,s2):
    '''
    The function `areAnagram(s1, s2)` checks if two strings are anagrams by first comparing their lengths; 
    if they differ, it returns `False`. It then initializes a count array of size 256 to zero, 
    which tracks character frequencies. As it iterates through both strings, 
    it increments the count for each character in `s1` and decrements it for each character in `s2`. 
    Finally, it verifies if all counts are zero; if any count is non-zero, it returns `False`, 
    indicating the strings are not anagrams. If all counts are zero, it returns `True`, 
    confirming the strings are anagrams. This method ensures an efficient linear time complexity, (O(n).
    
    '''
    if len(s1) != len(s2):
        return False
    count=[0]*256
    for i in range(len(s1)):
        count[ord(s1[i])]+=1
        count[ord(s2[i])]-=1
    for x in count:
        if x!=0:
            return False
    return True


print(areAnagram(s1,s2))
# Out:
# Enter a String:
# TASA
# Enter a String:
# sATYA
# False

# %% [markdown]
# Time Complexity: O(n), where n is the size of string
#
# Space Complexity: O(c) (where c is constant), because we are using a list of constant size.

# %% [markdown]
# #  <span style="color:blue">Leftmost Repeating Character
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Leftmost Repeating Character
# Efficient 1 

import sys
CHAR = 256
def leftmost(st) :
    findex = [-1] * CHAR
    res = sys.maxsize
    for i in range(len(st)) :
        if (findex[ord(st[i])]==-1) :
            findex[ord(st[i])] = i
        else :
            res = min(res,findex[ord(st[i])])
    if res == sys.maxsize :
        return -1
    else :
        return res
        
st = "abccbd"
print(leftmost(st))
# Out:
# 1

# %% [markdown]
#  Time complexity: O(n) where n is the size of string
#
# Space complexity: O(c) where c is constant ( size of list findex ).

# %% [markdown]
# #### Another Approach:

# %%
# Leftmost Repeating Character
# Efficient 2

CHAR = 256
def leftmost(st) :
    vis = [False] * CHAR
    res = -1
    for i in range(len(st)-1,-1,-1) :
        if (vis[ord(st[i])]==True) :
            res = i
        else :
            vis[ord(st[i])] = True
    
    return res
        
st = "abccbd"
print(leftmost(st))
# Out:
# 1

# %% [markdown]
#  Time complexity: O(n) where n is the size of string
#
# Space complexity: O(c) where c is constant ( size of list vis ).

# %%
CHAR = 256 
def leftmost(st) :
    count = [0] * CHAR 
    for i in range(len(st)) :
        count[ord(st[i])] += 1 
    for i in range(len(st)) :
        if count[ord(st[i])] > 1 :
            return i 
    return -1 
    
 
st = "abccbd"  
print(leftmost(st))
# Out:
# 1

# %% [markdown]
# Time complexity: O(n) where n is the size of string
#
# Space complexity: O(c) where c is constant ( size of list count ).

# %%
def leftmost(st) :
    for i in range(len(st)) :
        for j in range(i+1 , len(st)) :
            if st[i] == st[j] :
                return i 
            
    return -1 
    
st = "cabba"
print(leftmost(st))
# Out:
# 1

# %% [markdown]
#  Time complexity: O(n2) where n is the size of string
#
# Space complexity: O(1)

# %% [markdown]
# #  <span style="color:blue">Leftmost Non-Repeating Element
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python program to print the first non-repeating character

NO_OF_CHARS = 256

def getCharCountArray(string):
	count = [0] * NO_OF_CHARS
	for i in string:
		count[ord(i)]+= 1
	return count

def firstNonRepeating(string):
	count = getCharCountArray(string)
	index = -1
	k = 0

	for i in string:
		if count[ord(i)] == 1:
			index = k
			break
		k += 1

	return index

string = "geeksforgeeks"
index = firstNonRepeating(string)
if index == 1:
	print ("Either all characters are repeating or string is empty")
else:
	print ("First non-repeating character is" , string[index])
# Out:
# First non-repeating character is f

# %%
# Leftmost Non-Repeating Element
# Naive

import sys
CHAR = 256
def nonrep(st) :
    fi = [-1] * CHAR 
    for i in range(len(st)) :
        if fi[ord(st[i])] == -1 :
            fi[ord(st[i])] = i
        else :
            fi[ord(st[i])] = -2 
    res = sys.maxsize
    for i in range(CHAR) :
        if fi[i] >= 0 :
            res = min(res,fi[i])
    if res == sys.maxsize :
        return -1
    else :
        return res 
    
    
st = "apple"
print(nonrep(st))
# Out:
# 0

# %% [markdown]
# #  <span style="color:blue">Reverse words in a given string
# </span>

# %% [markdown]
# Reverse words in a given string
#
# Let the input string be “i like this program very much”. The function should change the string to “much very program this like i”

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Reverse words in a string


def reverse_word(s, start, end):
	while start < end:
		s[start], s[end] = s[end], s[start]
		start = start + 1
		end -= 1


s = "Welcome to dsa"


s = list(s)
start = 0
while True:
	
	try:
		end = s.index(' ', start)

		reverse_word(s, start, end - 1)

		start = end + 1

	except ValueError:

		reverse_word(s, start, len(s) - 1)
		break

s.reverse()

s = "".join(s)

print(s)
# Out:
# dsa to Welcome
