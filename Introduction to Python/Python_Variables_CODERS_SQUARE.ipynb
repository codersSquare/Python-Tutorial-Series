# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# # <center> Variables in Python </center>

# %% [markdown]
# - ###  A value is one of the basic things a program works with, like a letter or a number.
#
# - ### A variable is a name that refers to a value.
#
# - ### An assignment statement creates new variables and gives them value. This Variables are like containers and can be updated.
#
# - ### One of the most powerful features of a programming language is the ability to manipulate variables.

# %% [markdown]
# #### Let's create two variables and assign them values

# %%
a=5
b=7

# %%
a
# Out:
# 5

# %%
b
# Out:
# 7

# %%
print(a)
# Out:
# 5

# %% [markdown]
# #### Let's try updating the values and see what happens

# %%
a=10
a
# Out:
# 10

# %% [markdown]
# #### Now, variable names can take the following characters
# - (A-Z, a-z, 0-9, "_")
#
# #### But this shouldn't be similar to the python reserved words.

# %% [markdown]
# #### Let's see what are the reserved keywords in Python
#
#
# #### Python reserves 35 keywords:
# - and
# - del
# - from
# - None
# - True
# - as
# - elif
# - global
# - nonlocal
# - try
# - assert
# - else
# - if
# - not
# - while
# - break
# - except
# - import
# - or
# - with
# - class
# - False
# - in
# - pass
# - yield
# - continue
# - finally
# - is
# - raise
# - async
# - def
# - for
# - lambda
# - return
# - await

# %% [markdown]
# #### Now Let's try performing some calculation with variables

# %%
course_fee = 300
no_of_month = 6

# %%
total_fee = course_fee * no_of_month

# %%
print(f"total_fee is: {total_fee}")
# Out:
# total_fee is: 1800

# %% [markdown]
# ### Type of Variable:
#
#
# #### The type of a variable is the type of the value it refers to.

# %%
num_1 = 300
num_2 = "300"

# %%
type(num_1)
# Out:
# int

# %%
type(num_2)
# Out:
# str

# %%
num_3 = num_1 + num_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\LOGIST~1\AppData\Local\Temp/ipykernel_2264/1235190148.py in <module>
# ----> 1 num_3 = num_1 + num_2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### In this particular situation we use type conversion, a topic that we will be discussing in the upcoming lectures.

# %% [markdown]
# ### Thank You
